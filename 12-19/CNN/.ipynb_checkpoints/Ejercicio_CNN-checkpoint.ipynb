# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# Realizaremos un ejercicio descrito en el blog www.aprendemachinelearning.com para hacer reconocimiento de imágenes.

# %% [markdown]
# # Importar Librerías

# %%
import keras
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # Cargar set de Imágenes

# %%
dirname = os.path.join(os.getcwd(), 'animales_nuevo')
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\alexy\AppData\Local\Temp\ipykernel_19128\4228133641.py:14: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
# leyendo imagenes de  C:\trabajos-IA\12-19\CNN\animales_nuevo\
# C:\trabajos-IA\12-19\CNN\animales_nuevo\ants 1
# C:\trabajos-IA\12-19\CNN\animales_nuevo\cats 900
# C:\trabajos-IA\12-19\CNN\animales_nuevo\dogs 2027
# C:\trabajos-IA\12-19\CNN\animales_nuevo\ladybugs 2066
# C:\trabajos-IA\12-19\CNN\animales_nuevo\turtles 893
# Directorios leidos: 5
# Imagenes en cada directorio [901, 2027, 2066, 893, 2016]
# suma Total de imagenes en subdirs: 7903

# %% [markdown]
# # Creamos las etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  7903

# %%
animales=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    animales.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 ants
# 1 cats
# 2 dogs
# 3 ladybugs
# 4 turtles

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy

# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# # Creamos Sets de Entrenamiento y Test

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (6322, 224, 224, 3) (6322,)
# Testing data shape :  (1581, 224, 224, 3) (1581,)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 0')

# %% [markdown]
# # Preprocesamos las imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255.
test_X = test_X / 255.

# %% [markdown]
# ## Hacemos el One-hot Encoding para la red

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 4
# After conversion to one-hot: [0. 0. 0. 0. 1.]

# %% [markdown]
# # Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (5057, 224, 224, 3) (1265, 224, 224, 3) (5057, 5) (1265, 5)

# %% [markdown]
# # Creamos el modelo de CNN

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 30 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 64 # cantidad de imágenes que se toman a la vez en memoria

# %%
animal_model = Sequential()

# Entrada del modelo
animal_model.add(Input(shape=(224, 224, 3)))

# Bloque 1
animal_model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
animal_model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
animal_model.add(MaxPooling2D((2,2)))
animal_model.add(Dropout(0.25))

# Bloque 2
animal_model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
animal_model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
animal_model.add(MaxPooling2D((2,2)))
animal_model.add(Dropout(0.25))

# Bloque 3
animal_model.add(Conv2D(128, (3,3), padding="same", activation="relu"))
animal_model.add(Conv2D(128, (3,3), padding="same", activation="relu"))
animal_model.add(MaxPooling2D((2,2)))
animal_model.add(Dropout(0.25))

# Clasificador
animal_model.add(Flatten())
animal_model.add(Dense(256, activation="relu"))
animal_model.add(Dropout(0.5))
animal_model.add(Dense(nClasses, activation="softmax"))

# %%
animal_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 112, 112, 64)   │        18,496 │
# ...

# %%
animal_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# ----------------------------------------------------------------
# Data Augmentation
# ----------------------------------------------------------------

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Aumentación de datos
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(train_X)

# Callbacks para mejorar el entrenamiento
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ModelCheckpoint("modelo_animales_2.keras", save_best_only=True)
]

# %%
# ----------------------------------------------------------------
# ENTRENAMIENTO FINAL
# ----------------------------------------------------------------

history = animal_model.fit(
    datagen.flow(train_X, train_label, batch_size=batch_size),
    validation_data=(valid_X, valid_label),
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# C:\Users\alexy\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 422s 5s/step - accuracy: 0.4570 - loss: 1.2677 - val_accuracy: 0.5589 - val_loss: 1.0954
# Epoch 2/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 423s 5s/step - accuracy: 0.5472 - loss: 1.0228 - val_accuracy: 0.6142 - val_loss: 0.8628
# Epoch 3/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 416s 5s/step - accuracy: 0.5826 - loss: 0.9095 - val_accuracy: 0.6443 - val_loss: 0.7896
# Epoch 4/30
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 459s 6s/step - accuracy: 0.6095 - loss: 0.8599 - val_accuracy: 0.6498 - val_loss: 0.7505
# Epoch 5/30
# ...

# %% [markdown]
# # Evaluamos la red

# %%
test_eval = animal_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 370ms/step - accuracy: 0.7767 - loss: 0.5375

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.5375015139579773
# Test accuracy: 0.7767235636711121

# %%
accuracy = animal_model.history['accuracy']
val_accuracy = animal_model.history['val_accuracy']
loss = animal_model.history['loss']
val_loss = animal_model.history['val_loss']

epochs = range(len(accuracy))

# Plot accuracy
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot loss
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 accuracy = animal_model.history['accuracy']
#       2 val_accuracy = animal_model.history['val_accuracy']
#       3 loss = animal_model.history['loss']
#
# TypeError: 'History' object is not subscriptable

# %%
predicted_classes2 = animal_model.predict(test_X)
# Out:
# 13/50 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step

# %%
predicted_classes=[]
for predicted_sport in predicted_classes2:
    predicted_classes.append(predicted_sport.tolist().index(max(predicted_sport)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((1890,), (1890,))

# %% [markdown]
# # Aprendamos de los errores: Qué mejorar

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(224,224,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(animales[predicted_classes[correct]],
                                                    animales[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 1560 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(224,224,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(animales[predicted_classes[incorrect]],
                                                    animales[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 330 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.77      0.77       279
#      Class 1       0.76      0.79      0.77       437
#      Class 2       0.77      0.71      0.74       432
#      Class 3       0.89      0.88      0.88       323
#      Class 4       0.93      0.98      0.95       419
#
#     accuracy                           0.83      1890
#    macro avg       0.82      0.82      0.82      1890
# weighted avg       0.82      0.83      0.82      1890

# %% [markdown]
# # Prediccion de una nueva imagen

# %%
import os
import csv
import numpy as np
from PIL import Image
from keras.models import load_model

# ===========================
# 1️⃣ CONFIGURACIÓN
# ===========================
ruta_modelo = "modelo_animales.keras"       # tu modelo Keras entrenado
carpeta_imagenes = "imagenes_pruebas" # carpeta con imágenes nuevas
size = (224, 224)                        # tamaño usado en entrenamiento
animales = ["tortuga", "mariquita", "perro", "gato", "hormiga"]  # clases
archivo_salida = "predicciones.csv"      # CSV donde se guardarán resultados

# ===========================
# 2️⃣ CARGAR MODELO
# ===========================
model = load_model(ruta_modelo)
print("✅ Modelo cargado correctamente.")

# ===========================
# 3️⃣ PREDECIR IMÁGENES
# ===========================
resultados = []

archivos = [f for f in os.listdir(carpeta_imagenes)
            if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]

for img_name in archivos:
    ruta_img = os.path.join(carpeta_imagenes, img_name)
    try:
        # Cargar y preprocesar
        img = Image.open(ruta_img).convert("RGB")
        img = img.resize(size)
        img_array = np.array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)

        # Predecir
        pred = model.predict(img_array)
        clase_idx = np.argmax(pred[0])
        clase_nombre = animales[clase_idx]
        prob_max = float(pred[0][clase_idx])

        resultados.append([img_name, clase_nombre, prob_max])
        print(f"🟢 {img_name} -> {clase_nombre} ({prob_max:.2f})")

    except Exception as e:
        print(f"✗ Error con {img_name}: {e}")

# ===========================
# 4️⃣ GUARDAR RESULTADOS EN CSV
# ===========================
with open(archivo_salida, mode='w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(["imagen", "clase_predicha", "probabilidad"])
    writer.writerows(resultados)

print(f"\n🎉 Predicciones completadas y guardadas en {archivo_salida}")
# Out:
# ✅ Modelo cargado correctamente.
# WARNING:tensorflow:5 out of the last 69 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000017FF8DBF060> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 🟢 brown-chihuahua-2021-08-26-19-05-45-utc.jpg -> perro (0.49)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 🟢 donatello.jpg -> gato (0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# ...
